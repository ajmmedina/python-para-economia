# %% [markdown]
# # Lección 1: Tu primer programa en Python
#
# Python es un lenguaje de programación muy usado para:
#
# - análisis de datos
# - economía
# - finanzas
# - inteligencia artificial
#
# En este curso aprenderás a usar Python para resolver problemas económicos.

# %% [markdown]
# ## Mostrar texto en pantalla
#
# En Python usamos la función `print()` para mostrar mensajes.
#
# Ejemplo:
#
# > print("Hola mundo")
#
# Ahora escribe ese código en la celda de abajo.

# %% [markdown]
# ## Modifica el programa
#
# Haz que el programa muestre:
#
# > Hola, estoy aprendiendo Python para economía

# %% [markdown]
# ## Mostrar varias líneas
#
# Puedes usar `print()` varias veces.
#
# Ejemplo:
#
# > print("Economía")
#
# > print("Datos")
#
# > print("Python")
#
# Escribe ese código en la celda de abajo.

# %% [markdown]
# ## Reto económico
#
# Escribe un programa que muestre:
#
# > Estudio economía
#
# > Python me ayudará a analizar datos
